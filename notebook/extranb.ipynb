# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 12
#       1 models={
#       2         "Random Forest":" RandomForestRegressor()",
#       3         "Decision Tree": "DecisionTreeRegressor()",
#    (...)      9         "AdaBoost Regressor": 'AdaBoostRegressor()'
#      10     }
# ---> 12 a=models[sorted(models.values(),reverse=True)[0]]
#      13 a
#
# KeyError: 'zCatBoostRegressor(verbose=False)'
